# %% [markdown]
# # Netflix Data Analysis

# %% [markdown]
# ## 1. Data Loading

# %%
import pandas as pd

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-24d14b9b-a2e5-41be-823e-b4fa7a231e72" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-24d14b9b-a2e5-41be-823e-b4fa7a231e72">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# ## 2. Initial Data Exploration

# %%
df_raw=pd.read_csv('netflix_titles.csv')
df_raw.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
df_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
df_raw.shape
# Out:
# (8807, 12)

# %%
df_raw.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
df_raw.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %% [markdown]
# ## 3. Handling Missing Values

# %%
df=df_raw.copy()

# %%
#Clean
df['director']=df['director'].fillna('Unknown')
df['cast']=df['cast'].fillna('Unknown')
df['country']=df['country'].fillna('Unknown')
df.isnull().sum()
# Out:
# show_id          0
# type             0
# title            0
# director         0
# cast             0
# country          0
# date_added      10
# release_year     0
# rating           4
# duration         3
# listed_in        0
# description      0
# dtype: int64

# %%
#drop
df=df.dropna(subset=['date_added','rating','duration'])

# %%
df.isnull().sum()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# cast            0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# description     0
# dtype: int64

# %% [markdown]
# ## 4. Content Type Analysis

# %%
df['type'].value_counts()
# Out:
# type
# Movie      6126
# TV Show    2664
# Name: count, dtype: int64

# %%
df.groupby('release_year')['type'].value_counts().head(80)
# Out:
# release_year  type
# 1925          TV Show     1
# 1942          Movie       2
# 1943          Movie       3
# 1944          Movie       3
# 1945          Movie       3
#                          ..
# 2000          Movie      33
#               TV Show     4
# 2001          Movie      40
#               TV Show     5
# 2002          Movie      44
# Name: count, Length: 80, dtype: int64

# %% [markdown]
# ## 5. Feature Engineering: Decade

# %%
df['decade']=(df['release_year']//10)*10

# %%
df['decade']
# Out:
# 0       2020
# 1       2020
# 2       2020
# 3       2020
# 4       2020
#         ...
# 8802    2000
# 8803    2010
# 8804    2000
# 8805    2000
# 8806    2010
# Name: decade, Length: 8790, dtype: int64

# %%
df.groupby('decade')['type'].value_counts()
# Out:
# decade  type
# 1920    TV Show       1
# 1940    Movie        13
#         TV Show       2
# 1950    Movie        11
# 1960    Movie        23
#         TV Show       2
# 1970    Movie        66
#         TV Show       4
# 1980    Movie       122
#         TV Show       7
# 1990    Movie       241
#         TV Show      33
# 2000    Movie       677
#         TV Show     130
# 2010    Movie      4179
#         TV Show    1734
# 2020    Movie       794
#         TV Show     751
# Name: count, dtype: int64

# %% [markdown]
# ## 6. Country Analysis

# %%
df['country'].value_counts().head()
# Out:
# country
# United States     2809
# India              972
# Unknown            829
# United Kingdom     418
# Japan              243
# Name: count, dtype: int64

# %%
countries=['United States','India','Unknown','United Kingdom','Japan']
df_top=df[df['country'].isin(countries)]
df_top.groupby('country')['type'].value_counts()
# Out:
# country         type
# India           Movie       893
#                 TV Show      79
# Japan           TV Show     167
#                 Movie        76
# United Kingdom  TV Show     212
#                 Movie       206
# United States   Movie      2055
#                 TV Show     754
# Unknown         Movie       439
#                 TV Show     390
# Name: count, dtype: int64

# %%
df[df['type']=='Movie'].value_counts()
# Out:
# show_id  type   title                    director                        cast                                                                                                                                                                         country                 date_added          release_year  rating  duration  listed_in                                         description                                                                                                                                               decade
# ...

# %%
df['country'].nunique()
# Out:
# 749

# %%
df_india=df[df['country']=='India']
df_india.groupby('country')['type'].value_counts()
# Out:
# country  type
# India    Movie      893
#          TV Show     79
# Name: count, dtype: int64

# %%
df['decade'].value_counts().head(1)
# Out:
# decade
# 2010    5913
# Name: count, dtype: int64

# %%
three_countries=['United States','India','Unknown']
Top_Three_Countries=df[df['country'].isin(three_countries)]
Top_Three_Countries.groupby('country')['type'].value_counts()
# Out:
# country        type
# India          Movie       893
#                TV Show      79
# United States  Movie      2055
#                TV Show     754
# Unknown        Movie       439
#                TV Show     390
# Name: count, dtype: int64

# %%
Unknown=(len(df[df['country']=='Unknown'])/len(df.index))*100
print(f"Percentage of Unknown countries:{Unknown}")
# Out:
# Percentage of Unknown countries:9.431171786120592

# %% [markdown]
# ## 7. Genre Analysis

# %%
df['listed_in']=df['listed_in'].str.split(", ")

# %%
df=df.explode('listed_in')
df['listed_in'].value_counts().head()
# Out:
# listed_in
# International Movies      2752
# Dramas                    2426
# Comedies                  1674
# International TV Shows    1349
# Documentaries              869
# Name: count, dtype: int64

# %% [markdown]
# ## 8. Cast Analysis

# %%
df['cast']=df['cast'].str.split(", ")
df=df.explode('cast')
df['cast'].value_counts().head(10)
# Out:
# cast
# Unknown             1504
# Anupam Kher          120
# Shah Rukh Khan        99
# Naseeruddin Shah      92
# Akshay Kumar          85
# Paresh Rawal          79
# Om Puri               78
# Amitabh Bachchan      76
# Takahiro Sakurai      75
# Yuki Kaji             73
# Name: count, dtype: int64
